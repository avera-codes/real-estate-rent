# %% [markdown]
# # Введение
# В рамках данного проекта задача нашей команды подготовить данные для разработчиков машинного обучения. Наша команда подготовит датасет для обучения, используя таблицу, которую выгрузили дата инженеры

# %% [markdown]
# ## Сбор данных
# В рамках данного проекта наша команда работает с готовым набором данных https://github.com/Elbrus-DataScience/rent_real_estate/blob/master/_data.csv . Данные представлены в виде таблицы из 25 стобцов и 23367 значений.
# | Column                     | Non-Null Count | Dtype    |
# |----------------------------|----------------|----------|
# | Unnamed: 0                 | 23368          | int64    |
# | ID объявления              | 23368          | int64    |
# | Количество комнат          | 22327          | object   |
# | Тип                        | 23368          | object   |
# | Метро                      | 22053          | object   |
# | Адрес                      | 23368          | object   |
# | Площадь, м2                | 23368          | object   |
# | Дом                        | 23368          | object   |
# | Парковка                   | 9951           | object   |
# | Цена                       | 23368          | object   |
# | Телефоны                   | 23368          | object   |
# | Описание                   | 23368          | object   |
# | Ремонт                     | 20613          | object   |
# | Площадь комнат, м2         | 14458          | object   |
# | Балкон                     | 15390          | object   |
# | Окна                       | 16755          | object   |
# | Санузел                    | 20696          | object   |
# | Можно с детьми/животными   | 17272          | object   |
# | Дополнительно              | 23011          | object   |
# | Название ЖК                | 5848           | object   |
# | Серия дома                 | 2163           | object   |
# | Высота потолков, м         | 11206          | float64  |
# | Лифт                       | 17868          | object   |
# | Мусоропровод               | 12846          | object   |
# | Ссылка на объявление       | 23368          | object   |

# %% [markdown]
# ## Обработка

# %% [markdown]
# Первым этапом наша команда будет обрбатывать данные, очищать их от дубликатов и заполнять пустые значения. Будут добавлены новые значения на основе тех, которые уже есть. Также мы не будем использовать ненужные в рамках данной задачи данные и с целью более удобной работы сделаем копию датасета без ненужных столбцов.

# %% [markdown]
# ## Визуализация

# %% [markdown]
# Полученные результаты мы визуализируем для лучшего понимания данных.

# %% [markdown]
# ## Анализ

# %% [markdown]
# Далее мы обработаем датасет, проведем анализ полученных очищенных данных и поработаем над выбросами. Проанализируем влияние добавленных данных на предсказательную модель.

# %% [markdown]
# ## Категориальные признаки

# %% [markdown]
# Также мы преобразуем категориальные фичи в числовой формат

# %% [markdown]
# # Релизы

# %% [markdown]
# Работа над проектом осуществлена в 3 релизах

# %% [markdown]
# ## Релиз 1.0
# Коммит* с результатами EDA или разведочного анализа данных - Exploratory Data Analysis. Например, html-отчёт EDA.html сформированный из EDA.ipynb. Это необходимо, чтобы топы компании могли понять из отчёта что из себя представляют данные, больше графиков и агрегированной информации, минимум кода в html файле
# состав репозитория на данном релизе:
# - README.md описание задачи над которой вы работаете, а также в каком составе
# - EDA.html - отчет из графиков и текстового описания
# - EDA.ipynb - jupyter notebook, в котором вы делали графики и изучали данные

# %% [markdown]
# ## Релиз 2.0
# Результаты очистки данных от пропусков.
#
# Состав репозитория дополняется:
# - preprocessing.ipynb - jupyter notebook файл, где показан процесс обработки данных
# - data.csv

# %% [markdown]
# ## Релиз 3.0
# Финальный. Коммит данных с новыми фичами (feature engineering) - это тот же файл preprocessing.ipynb, но уже отрефакторенный с прошлого релиза и файл data.csv c новыми колонками.
#
# в составе репозитория изменения:
# - README.md добавлены основные выводы и иллюстрации
# - data.csv - полностью отвечающий предыдущим и новым критериям
# - preprocessing.ipynb - jupyter notebook файл, где показан весь процесс обработки данных с комментариями, которые объясняют мотивацию принятия тех или иных решений в ходе работы
